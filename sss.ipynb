# %%
import math
x = 10
for _ in range(10):
    x = math.log((x-0.01) / x)
    print(x)
# Out:
# -0.010005003335835344
# 6.928971076067971
# -0.014442581617358598
# 5.2614585969910035
# -0.019024221025411337
# 4.2241773104570255
# -0.023701314131747454
# 3.5200633640456553
# -0.02844900847829972
# 3.012195997316065
